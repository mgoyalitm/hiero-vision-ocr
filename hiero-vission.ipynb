# %% [markdown]
# # Hiero Vission OCR

# %%
import torch
from torch import nn
import torchvision
from torchvision import datasets
from torchvision.transforms import ToTensor
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import requests
from pathlib import Path
from timeit import default_timer as timer
from tqdm.auto import tqdm
import pandas as pd
import random

batch_size = 1
num_workers = 1
RandomSeed = 42
mnist_path = Path.cwd().parent / "mnist-dataset" 
device = "cuda" if torch.cuda.is_available() else "cpu"

print(f"Batch Size: {batch_size}")
print(f"Number of Workers: {num_workers}")
print(f"MNIST directory: {mnist_path}")
print(f"device: {device}")
print(f"PyTorch version {torch.__version__}")
print(f"Torch Vission: {torchvision.__version__}")
# Out:
# Batch Size: 1
# Number of Workers: 1
# MNIST directory: /mnt/c/Repositories/mgoyalitm/mnist-dataset
# device: cuda
# PyTorch version 2.5.1+cu121
# Torch Vission: 0.20.1+cu121

# %% [markdown]
# ## Datasets & Dataloaders

# %%
from hiero_datasets import dnn_dataset, gbdt_dataset

dnn_set = dnn_dataset(root_dir=mnist_path)
gbdt_set = gbdt_dataset(root_dir=mnist_path)

dnn_dataloader = DataLoader(dataset=dnn_set, batch_size=batch_size, shuffle=True, num_workers=num_workers)
gbdt_dataloader = DataLoader(dataset=gbdt_set, batch_size=batch_size, shuffle=True, num_workers=num_workers)

# %% [markdown]
# ### Visualize & validate dataset

# %%
from visualization import display_random_mnist_samples
display_random_mnist_samples(dnn_set, 42, 2, 24)
